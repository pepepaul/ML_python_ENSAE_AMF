# %%
import pandas as pd

# %%
X_train = pd.read_csv("AMF_train_X.csv", index_col=0)
Y_train = pd.read_csv("AMF_train_Y.csv", index_col=0)

# %%
X_train
# Out:
#            Share      Day     Trader       OTR         OCR         OMR  \
# Index
# 1         Isin_8  Date_24  Trader_10  2.272727    8.333333   12.500000
# 2        Isin_87  Date_29  Trader_10  1.696629   25.166667   21.571429
# 3        Isin_87  Date_23  Trader_10  1.482759   47.300000  118.250000
# 4        Isin_12  Date_11  Trader_10  1.705882   14.500000   29.000000
# 5        Isin_87   Date_9  Trader_10  1.517730   26.750000         NaN
# ...          ...      ...        ...       ...         ...         ...
# 105778   Isin_84  Date_27  Trader_60  1.150000   23.000000         NaN
# 105779  Isin_102  Date_18  Trader_60  1.352941   23.000000         NaN
# 105780   Isin_12  Date_13  Trader_60  1.146667   86.000000         NaN
# 105781   Isin_27  Date_30  Trader_60  1.179191  204.000000         NaN
# 105782   Isin_47  Date_12  Trader_60  1.178571   66.000000         NaN
#
#         min_time_two_events  mean_time_two_events  10_p_time_two_events  \
# Index
# ...

# %%
X_train.Day.unique().shape
# Out:
# (22,)

# %%
X_train.Share.unique().shape
# Out:
# (119,)

# %%
22*119*86
# Out:
# 225148

# %%
X_train.shape[0]
# Out:
# 105782

# %%
#Pourcentage de NaN dans les données
print("Pourcentage de NaN dans les données")
print(X_train.isna().sum()/X_train.shape[0]*100)
# Out:
# Pourcentage de NaN dans les données
# Share                          0.000000
# Day                            0.000000
# Trader                         0.000000
# OTR                            1.591008
# OCR                            0.000000
# OMR                           45.009548
# min_time_two_events            0.000000
# mean_time_two_events           0.000000
# 10_p_time_two_events           0.000000
# med_time_two_events            0.000000
# 25_p_time_two_events           0.000000
# 75_p_time_two_events           0.000000
# 90_p_time_two_events           0.000000
# max_time_two_events            0.000000
# min_lifetime_cancel            0.000000
# mean_lifetime_cancel           0.000000
# 10_p_lifetime_cancel           0.000000
# med_lifetime_cancel            0.000000
# 25_p_lifetime_cancel           0.000000
# 75_p_lifetime_cancel           0.000000
# 90_p_lifetime_cancel           0.000000
# max_lifetime_cancel            0.000000
# ...

# %%
X_train.columns
# Out:
# Index(['Share', 'Day', 'Trader', 'OTR', 'OCR', 'OMR', 'min_time_two_events',
#        'mean_time_two_events', '10_p_time_two_events', 'med_time_two_events',
#        '25_p_time_two_events', '75_p_time_two_events', '90_p_time_two_events',
#        'max_time_two_events', 'min_lifetime_cancel', 'mean_lifetime_cancel',
#        '10_p_lifetime_cancel', 'med_lifetime_cancel', '25_p_lifetime_cancel',
#        '75_p_lifetime_cancel', '90_p_lifetime_cancel', 'max_lifetime_cancel',
#        'NbTradeVenueMic', 'MaxNbTradesBySecond', 'MeanNbTradesBySecond',
#        'min_dt_TV1', 'mean_dt_TV1', 'med_dt_TV1', 'min_dt_TV1_TV2',
#        'mean_dt_TV1_TV2', 'med_dt_TV1_TV2', 'min_dt_TV1_TV3',
#        'mean_dt_TV1_TV3', 'med_dt_TV1_TV3', 'min_dt_TV1_TV4',
#        'mean_dt_TV1_TV4', 'med_dt_TV1_TV4', 'NbSecondWithAtLeatOneTrade'],
#       dtype='object')

# %%
Y_train
# Out:
#                type
# Trader
# Trader_285      MIX
# Trader_114  NON HFT
# Trader_110  NON HFT
# Trader_57   NON HFT
# Trader_128  NON HFT
# ...             ...
# Trader_140      MIX
# Trader_451      MIX
# Trader_438      MIX
# Trader_278      HFT
# Trader_330      MIX
#
# [86 rows x 1 columns]

# %%
X_test = pd.read_csv("AMF_test_X.csv", index_col=0)
results_rf_bench = pd.read_csv("random_file.csv", index_col=0)

# %%
X_test
# Out:
#           Share      Day            Trader       OTR        OCR         OMR  \
# Index
# 1      Isin_106  Date_12          Adelaide  1.114754  68.000000         NaN
# 2       Isin_94   Date_2          Adelaide  1.666667   5.000000         NaN
# 3      Isin_106  Date_13          Adelaide  1.088235  37.000000         NaN
# 4      Isin_106   Date_7          Adelaide  2.250000   4.500000         NaN
# 5      Isin_106  Date_20          Adelaide  1.266667  19.000000         NaN
# ...         ...      ...               ...       ...        ...         ...
# 85300   Isin_63  Date_22  The Magic Mirror  2.871595   5.857143  123.000000
# 85301   Isin_64  Date_17  The Magic Mirror  5.212121   3.071429         NaN
# 85302   Isin_68   Date_2  The Magic Mirror  4.455210   3.856013   16.355705
# 85303   Isin_70   Date_5  The Magic Mirror  6.447761   2.989619  432.000000
# 85304   Isin_80   Date_7  The Magic Mirror  7.700315   2.630388  135.611111
#
# ...

# %%
results_rf_bench
# Out:
#                      type
# Trader
# Adelaide          NON HFT
# Alana             NON HFT
# Alcmene               MIX
# Alice                 MIX
# Alices Sister     NON HFT
# ...                   ...
# Monstro           NON HFT
# Morgana               MIX
# The Doorknob          HFT
# The Doorman           MIX
# The Magic Mirror  NON HFT
#
# [85 rows x 1 columns]
